# %%
from sklearn.ensemble import RandomForestClassifier
from sklearn.model_selection import train_test_split
from sklearn.metrics import accuracy_score
import numpy as np

dataset = '../magic_dataset/magic04.csv'

data = np.genfromtxt(dataset, delimiter=',', skip_header=1)
X = data[:, :-1]
y = data[:, -1]

X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.2, random_state=45)

rf = RandomForestClassifier(n_estimators=50, max_depth=10, min_samples_split=2, random_state=45, verbose=1)
rf.fit(X_train, y_train)
y_pred = rf.predict(X_test)
accuracy = accuracy_score(y_test, y_pred)
print(f"Accuracy: {accuracy * 100:.2f}%")
# Out:
# [Parallel(n_jobs=1)]: Using backend SequentialBackend with 1 concurrent workers.
# Accuracy: 87.04%
# [Parallel(n_jobs=1)]: Done  50 out of  50 | elapsed:    4.8s finished
# [Parallel(n_jobs=1)]: Using backend SequentialBackend with 1 concurrent workers.
# [Parallel(n_jobs=1)]: Done  50 out of  50 | elapsed:    0.0s finished
